# %%
# %reload_ext autoreload
# %autoreload 2
import os
from pathlib import Path
import numpy as np
import pandas as pd
from aldiscore.prediction import utils
from aldiscore import ROOT, RSTATE
from aldiscore.constants.constants import STAT_SEP

# %%
data_dir = Path("/hits/fast/cme/bodynems/data/paper")
feat_df, drop_df, label_df = utils.load_features(
    data_dir,
    exclude_features=["is_dna", "num_seqs", "seq_length"],
)
clean_feat_names = feat_df.columns.str.replace(":", STAT_SEP).to_list()
feat_df.columns = clean_feat_names

print(feat_df.shape)
print(drop_df.shape)
print(label_df.shape)
# Out:
# Dropping 0 NaN rows...
# (11431, 469)
# (11431, 21)
# (11431, 1)

# %%
feat_df.columns[feat_df.columns.str.contains("ratio")]
# Out:
# Index(['min.psa_score_ratio', 'max.psa_score_ratio', 'mean.psa_score_ratio',
#        'std.psa_score_ratio', 'p1.psa_score_ratio', 'p5.psa_score_ratio',
#        'p10.psa_score_ratio', 'p20.psa_score_ratio', 'p30.psa_score_ratio',
#        'p40.psa_score_ratio', 'p50.psa_score_ratio', 'p60.psa_score_ratio',
#        'p70.psa_score_ratio', 'p80.psa_score_ratio', 'p90.psa_score_ratio',
#        'p95.psa_score_ratio', 'p99.psa_score_ratio', 'iqr.psa_score_ratio'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

train_idxs, test_idxs = train_test_split(
    feat_df.index.to_list(), test_size=0.2, random_state=RSTATE
)
test_idxs, valid_idxs = train_test_split(test_idxs, test_size=0.5, random_state=RSTATE)
print(len(train_idxs), len(test_idxs), len(valid_idxs))
#
X_train = feat_df.loc[train_idxs]
X_test = feat_df.loc[test_idxs]
X_valid = feat_df.loc[valid_idxs]
y_train = label_df.loc[train_idxs].iloc[:, 0]
y_test = label_df.loc[test_idxs].iloc[:, 0]
y_valid = label_df.loc[valid_idxs].iloc[:, 0]

# %%
from aldiscore.prediction.predictor import DifficultyPredictor

model = DifficultyPredictor("latest").model
imps = model.feature_importance("gain")
imps
# Out:
# array([1.76741837e+01, 9.05170046e-01, 3.90400951e+00, 7.21766775e-01,
#        2.85076636e+00, 3.86365895e-01, 1.89703203e+00, 1.17691104e+00,
#        1.95932649e+00, 1.74592337e+00, 2.98750874e+00, 2.84242599e+00,
#        1.49776667e+00, 1.32534720e+00, 1.22621959e+00, 4.88946049e-01,
#        6.22372606e+00, 1.84989891e+00, 1.80195625e+00, 2.95652074e-01,
#        1.34479599e+00, 2.59816165e-01, 1.43629467e+00, 3.49476777e-01,
#        8.17355616e-01, 5.52849846e-01, 1.58785373e+00, 2.51189344e-01,
#        2.35340762e+00, 3.08336830e-01, 1.30970047e+00, 3.51171937e-01,
#        1.34123452e+00, 5.01085110e-01, 1.65315017e+00, 3.31618284e-01,
#        2.43797917e+00, 7.65375974e-01, 1.74084122e+00, 8.52230917e-01,
#        1.07656568e+00, 1.44448557e+00, 1.73289180e+00, 9.55300525e-01,
#        2.34454238e+00, 2.07488100e+00, 2.50125267e+00, 1.26879574e+00,
#        1.68873220e+00, 7.03280715e-01, 1.83535895e+00, 3.55606598e-01,
#        1.68818849e+00, 6.90179662e-01, 1.22929783e+00, 4.05984957e-01,
#        1.79164529e+00, 6.29578186e-01, 1.31104042e+00, 6.00847930e-01,
#        8.96784612e-01, 4.07825246e-01, 1.64375014e+00, 2.73769980e-01,
#        2.71874844e+00, 3.64825225e-01, 5.74262380e-01, 6.68989368e-01,
#        1.72314508e+00, 4.69341536e-01, 7.00739081e-01, 7.03890818e-01,
#        1.54373974e+00, 3.13377614e-01, 3.26119897e+00, 3.36105600e-01,
#        1.29136519e+00, 7.63227686e-01, 1.95572061e+00, 5.11705736e-01,
#        1.86298526e+00, 3.58465812e-01, 1.34222238e+00, 2.62570793e-01,
#        1.05252406e+00, 5.19935904e-01, 1.09089379e+00, 5.25691112e-01,
#        2.47455098e+00, 3.07944632e-01, 1.63047527e+00, 4.32822737e-01,
#        3.34075678e+00, 4.34052195e-01, 3.11520492e+00, 7.48845559e-01,
#        1.96530433e+00, 6.67187545e-01, 1.42081373e+00, 3.92533704e-01,
#        1.55638739e+00, 5.87204290e-01, 2.52420378e+00, 1.18192104e+00,
#        2.01400382e+00, 7.46569747e-01, 2.05589085e+00, 4.67970678e-01,
#        2.66199669e+00, 4.29801835e-01, 1.15058665e+00, 5.10730398e-01,
#        1.08905579e+00, 3.23289359e-01, 1.01639925e+00, 1.07488918e+00,
#        1.72089166e+00, 1.52068373e+00, 1.19882277e+00, 7.52734309e-01,
#        2.26023833e+00, 4.50181700e-01, 1.73920972e+00, 2.88752963e-01,
#        2.35091570e+00, 9.37884258e-01, 8.42545785e-01, 1.24061062e+00,
#        1.14565092e+00, 4.24751893e+01, 7.62158895e+00, 1.49790434e+00,
#        1.65347296e+01, 2.54069707e+00, 6.71191069e+01, 5.03670902e+01,
#        1.16088208e+02, 1.83416309e+02, 3.37911383e+01, 6.27390752e+00,
#        1.88138016e+02, 7.07716135e-01, 1.01804148e+02, 2.89923520e-01,
#        7.22350121e+00, 2.47797059e-01, 2.26548652e+01, 1.81160256e+01,
#        5.73117845e+00, 2.21184580e+00, 5.41064904e+01, 1.22845185e+00,
#        2.90593581e+01, 8.55118426e-01, 8.16859849e+01, 6.55411218e+01,
#        2.83378463e+02, 1.74168934e+02, 1.60201955e+01, 6.54728856e+00,
#        8.73369836e+01, 3.36949895e+00, 5.63790233e+00, 1.90188675e-01,
#        4.12428019e+00, 1.67807816e+00, 8.18503441e+00, 2.33557908e-01,
#        1.00841088e+00, 6.24474641e-01, 3.23400155e+00, 6.91862534e-01,
#        3.56780520e+00, 1.53275194e+00, 1.21235807e+01, 1.12028676e+01,
#        5.20027492e+00, 2.66070709e+00, 7.47356918e+00, 2.28708940e+00,
#        8.52024123e+00, 2.55565189e-01, 5.83458372e-01, 1.00922976e+02,
#        1.23133672e+01, 2.68046207e+00, 1.38462661e+01, 8.07009221e-01,
#        2.73199057e+01, 1.05474152e+00, 5.98068310e+02, 7.53585975e+00,
#        3.33878360e+02, 7.71835105e+01, 1.21167471e+02, 3.37600114e+00,
#        3.12550074e+00, 3.62508796e-01, 4.52600269e+00, 1.81452713e+01,
#        1.40304726e+00, 6.71891718e+01, 1.39337272e+01, 1.20790501e+00,
#        1.65063574e+01, 5.18674601e+00, 2.16323165e+01, 1.81446136e+02,
#        1.37092505e+02, 3.43577263e+01, 5.13381378e+02, 1.51110671e+01,
#        9.34252024e+01, 7.50067500e-01, 2.91979326e+01, 4.92534704e-01,
#        1.62124015e+01, 3.41009918e+00, 5.64393669e+00, 1.88736160e+01,
#        5.41854258e+00, 1.09228602e+00, 1.17261703e+01, 7.04823267e-01,
#        5.05796152e+01, 6.55493306e+00, 1.42483141e+01, 3.83819144e+00,
#        1.87884172e+01, 3.52057809e+00, 8.00909930e+01, 1.26363323e+01,
#        3.27469350e+01, 3.26890961e+01, 4.84489482e+00, 1.47951064e-01,
#        1.58106665e+00, 3.61640921e+00, 1.25944493e+00, 3.84384293e+00,
#        7.72789440e+00, 2.25419819e+00, 6.69240777e+00, 1.44599443e+00,
#        1.05908537e+01, 5.61924272e+00, 1.42384806e+01, 2.25127886e+00,
#        3.53908934e+00, 2.04742386e+00, 3.22517071e+00, 5.02302175e-01,
#        2.16230991e+00, 2.68396214e-01, 2.34805945e+00, 6.57674677e-01,
#        1.94534276e+00, 5.51617033e-01, 2.44602884e+00, 6.19412168e-02,
#        3.16047349e-01, 2.38834529e-01, 2.74839620e+00, 1.12897942e+00,
#        1.39011688e+00, 1.64224037e-01, 9.65042286e-01, 4.88768233e-01,
#        1.70007150e+00, 2.34534399e+00, 7.90712519e-01, 3.41386122e-01,
#        4.16059323e+00, 2.10178246e+00, 1.74022565e+00, 2.29135783e+00,
#        7.55199319e+00, 2.95443016e+00, 8.21407835e+00, 3.21766496e+00,
#        1.60629045e+01, 1.19122753e+00, 2.37550307e+00, 1.19094730e+00,
#        3.71911135e+00, 7.45746451e-01, 2.69246820e+00, 1.11336795e+00,
#        2.02510648e+00, 3.51628437e-02, 4.28551772e+00, 3.37296847e-01,
#        2.85723249e+00, 7.51931820e-01, 1.64338016e+01, 3.17610568e+00,
#        7.26738362e+00, 7.86257184e-01, 4.70242468e+00, 5.86570036e+00,
#        9.60444105e+00, 1.88127467e+00, 4.03154750e+00, 3.79964871e+00,
#        3.65383980e+00, 7.52646595e-01, 2.31110989e+00, 0.00000000e+00,
#        1.58275618e-01, 2.40507447e+00, 4.94930429e-01, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.81131400e-04, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.15944648e-01,
#        1.60064817e-01, 2.74318915e-01, 2.25727515e-02, 1.71902030e+00,
#        2.83251107e-02, 2.49460142e+00, 1.04622835e+00, 1.57598324e+00,
#        1.34487169e+00, 2.71960806e+00, 3.76938012e-01, 1.42903994e+00,
#        6.14737658e-01, 1.36893081e+00, 1.63701193e+00, 3.71950194e+00,
#        1.34467868e+00, 2.21915710e+00, 2.05514630e-01, 2.10007318e+00,
#        5.58829458e-01, 3.38410502e+00, 1.03052024e+00, 7.16679344e-01,
#        8.89104218e-01, 1.91821590e+00, 9.11464257e-01, 1.18590076e+00,
#        4.00496445e-01, 8.60740371e-01, 2.12590016e-01, 1.02221345e+00,
#        3.54253432e-01, 1.16490912e+00, 1.94795974e-01, 6.80925177e-01,
#        6.85924655e-01, 1.18187669e+00, 5.34391375e-01, 1.51178179e+00,
#        5.25221328e-01, 2.41061798e+00, 4.19991275e-01, 2.49731040e+01,
#        1.79652017e+00, 1.72643277e+00, 5.45915869e-01, 2.18112635e+01,
#        4.63142467e-01, 2.50807070e+00, 3.80439804e-01, 2.63181327e+00,
#        6.60449845e-01, 1.24244557e+00, 3.00478756e-01, 3.52960429e+00,
#        1.06189957e+00, 9.58369097e-01, 4.05768964e-01, 1.31723315e+00,
#        1.25894973e+00, 1.98116694e+00, 6.76551036e+00, 1.12384275e+00,
#        5.61286947e-01, 7.38127690e-01, 7.03560807e-01, 1.62469094e+00,
#        1.13528913e+00, 2.36791579e+00, 4.53040277e-01, 2.18802568e+00,
#        6.29630575e-01, 1.88185147e+00, 1.56229373e+00, 3.02466246e+00,
#        6.43799955e+00, 5.50654708e+00, 6.11875234e-01, 1.29938832e+01,
#        1.56865834e+00, 5.22295599e+01, 8.91035940e-01, 2.06563625e+00,
#        3.96440905e+01, 2.00672252e+00, 1.23912395e+00, 2.35029184e+00,
#        1.78235867e+01, 1.70558204e+00, 1.25662021e+00, 3.07756039e+00,
#        1.15996947e+00, 1.78493433e+00, 1.97657472e+00, 1.52459681e+00,
#        7.94045629e-01, 1.84647741e+00, 5.46973521e+00, 1.66075221e+00,
#        7.51735633e-01, 1.87188347e+00, 1.19720651e+00, 7.75938592e-01,
#        1.66734256e+00, 1.23723445e+00, 7.95242690e-01, 1.41272879e+00,
#        1.36327438e+00, 1.16205099e+00, 1.37568613e+00, 1.82691616e+00,
#        1.06094737e+01, 3.10809164e+00, 7.19720969e-01, 2.99322944e+00,
#        3.02682584e+00, 1.33574774e+00, 2.49266597e+00, 2.01684965e+00,
#        1.05892196e+01, 1.53186768e+00, 2.33609047e+00, 3.05270441e+00,
#        2.92355776e+00, 2.53267809e+00, 1.11002725e+00, 6.80212389e+00,
#        2.09759123e+00, 1.04550948e+00, 3.03502111e+00, 1.44017575e+00,
#        2.62075591e+00, 1.97924503e+00, 1.35264182e+01, 1.64694920e+00,
#        2.99993654e+00, 2.77507811e+00, 2.35352262e+00, 1.76969425e+00,
#        4.49248813e+00, 3.01537910e+00, 1.50188508e+00, 8.04075956e-01,
#        2.32632183e+00, 9.40890729e-01, 2.16614466e+00, 1.70426406e+00,
#        3.00164412e+01])

# %%
clean_feat_names
# Out:
# ['lower_bound_gap_percentage',
#  'min.js_char',
#  'max.js_char',
#  'mean.js_char',
#  'std.js_char',
#  'p1.js_char',
#  'p5.js_char',
#  'p10.js_char',
#  'p20.js_char',
#  'p30.js_char',
#  'p40.js_char',
#  'p50.js_char',
#  'p60.js_char',
#  'p70.js_char',
#  'p80.js_char',
#  'p90.js_char',
#  'p95.js_char',
#  'p99.js_char',
#  'iqr.js_char',
#  'min.js_hpoly_count',
#  'max.js_hpoly_count',
#  'mean.js_hpoly_count',
#  'std.js_hpoly_count',
#  'p1.js_hpoly_count',
#  'p5.js_hpoly_count',
#  'p10.js_hpoly_count',
#  'p20.js_hpoly_count',
#  'p30.js_hpoly_count',
#  'p40.js_hpoly_count',
#  'p50.js_hpoly_count',
#  'p60.js_hpoly_count',
#  'p70.js_hpoly_count',
#  'p80.js_hpoly_count',
#  'p90.js_hpoly_count',
#  'p95.js_hpoly_count',
#  'p99.js_hpoly_count',
#  'iqr.js_hpoly_count',
#  'min.js_hpoly_len',
#  'max.js_hpoly_len',
#  'mean.js_hpoly_len',
#  'std.js_hpoly_len',
#  'p1.js_hpoly_len',
#  'p5.js_hpoly_len',
#  'p10.js_hpoly_len',
#  'p20.js_hpoly_len',
#  'p30.js_hpoly_len',
#  'p40.js_hpoly_len',
#  'p50.js_hpoly_len',
#  'p60.js_hpoly_len',
#  'p70.js_hpoly_len',
#  'p80.js_hpoly_len',
#  'p90.js_hpoly_len',
#  'p95.js_hpoly_len',
#  'p99.js_hpoly_len',
#  'iqr.js_hpoly_len',
#  'min.frst_entropy',
#  'max.frst_entropy',
#  'mean.frst_entropy',
#  'std.frst_entropy',
#  'p1.frst_entropy',
#  'p5.frst_entropy',
#  'p10.frst_entropy',
#  'p20.frst_entropy',
#  'p30.frst_entropy',
#  'p40.frst_entropy',
#  'p50.frst_entropy',
#  'p60.frst_entropy',
#  'p70.frst_entropy',
#  'p80.frst_entropy',
#  'p90.frst_entropy',
#  'p95.frst_entropy',
#  'p99.frst_entropy',
#  'iqr.frst_entropy',
#  'min.frst_inv-chi-square',
#  'max.frst_inv-chi-square',
#  'mean.frst_inv-chi-square',
#  'std.frst_inv-chi-square',
#  'p1.frst_inv-chi-square',
#  'p5.frst_inv-chi-square',
#  'p10.frst_inv-chi-square',
#  'p20.frst_inv-chi-square',
#  'p30.frst_inv-chi-square',
#  'p40.frst_inv-chi-square',
#  'p50.frst_inv-chi-square',
#  'p60.frst_inv-chi-square',
#  'p70.frst_inv-chi-square',
#  'p80.frst_inv-chi-square',
#  'p90.frst_inv-chi-square',
#  'p95.frst_inv-chi-square',
#  'p99.frst_inv-chi-square',
#  'iqr.frst_inv-chi-square',
#  'min.frst_mean',
#  'max.frst_mean',
#  'mean.frst_mean',
#  'std.frst_mean',
#  'p1.frst_mean',
#  'p5.frst_mean',
#  'p10.frst_mean',
#  'p20.frst_mean',
#  'p30.frst_mean',
#  'p40.frst_mean',
#  'p50.frst_mean',
#  'p60.frst_mean',
#  'p70.frst_mean',
#  'p80.frst_mean',
#  'p90.frst_mean',
#  'p95.frst_mean',
#  'p99.frst_mean',
#  'iqr.frst_mean',
#  'min.frst_serial-correlation',
#  'max.frst_serial-correlation',
#  'mean.frst_serial-correlation',
#  'std.frst_serial-correlation',
#  'p1.frst_serial-correlation',
#  'p5.frst_serial-correlation',
#  'p10.frst_serial-correlation',
#  'p20.frst_serial-correlation',
#  'p30.frst_serial-correlation',
#  'p40.frst_serial-correlation',
#  'p50.frst_serial-correlation',
#  'p60.frst_serial-correlation',
#  'p70.frst_serial-correlation',
#  'p80.frst_serial-correlation',
#  'p90.frst_serial-correlation',
#  'p95.frst_serial-correlation',
#  'p99.frst_serial-correlation',
#  'iqr.frst_serial-correlation',
#  'min.tc_base_min',
#  'max.tc_base_min',
#  'mean.tc_base_min',
#  'std.tc_base_min',
#  'p1.tc_base_min',
#  'p5.tc_base_min',
#  'p10.tc_base_min',
#  'p20.tc_base_min',
#  'p30.tc_base_min',
#  'p40.tc_base_min',
#  'p50.tc_base_min',
#  'p60.tc_base_min',
#  'p70.tc_base_min',
#  'p80.tc_base_min',
#  'p90.tc_base_min',
#  'p95.tc_base_min',
#  'p99.tc_base_min',
#  'iqr.tc_base_min',
#  'min.tc_base_mean',
#  'max.tc_base_mean',
#  'mean.tc_base_mean',
#  'std.tc_base_mean',
#  'p1.tc_base_mean',
#  'p5.tc_base_mean',
#  'p10.tc_base_mean',
#  'p20.tc_base_mean',
#  'p30.tc_base_mean',
#  'p40.tc_base_mean',
#  'p50.tc_base_mean',
#  'p60.tc_base_mean',
#  'p70.tc_base_mean',
#  'p80.tc_base_mean',
#  'p90.tc_base_mean',
#  'p95.tc_base_mean',
#  'p99.tc_base_mean',
#  'iqr.tc_base_mean',
#  'min.tc_base_std',
#  'max.tc_base_std',
#  'mean.tc_base_std',
#  'std.tc_base_std',
#  'p1.tc_base_std',
#  'p5.tc_base_std',
#  'p10.tc_base_std',
#  'p20.tc_base_std',
#  'p30.tc_base_std',
#  'p40.tc_base_std',
#  'p50.tc_base_std',
#  'p60.tc_base_std',
#  'p70.tc_base_std',
#  'p80.tc_base_std',
#  'p90.tc_base_std',
#  'p95.tc_base_std',
#  'p99.tc_base_std',
#  'iqr.tc_base_std',
#  'min.tc_base_max',
#  'max.tc_base_max',
#  'mean.tc_base_max',
#  'std.tc_base_max',
#  'p1.tc_base_max',
#  'p5.tc_base_max',
#  'p10.tc_base_max',
#  'p20.tc_base_max',
#  'p30.tc_base_max',
#  'p40.tc_base_max',
#  'p50.tc_base_max',
#  'p60.tc_base_max',
#  'p70.tc_base_max',
#  'p80.tc_base_max',
#  'p90.tc_base_max',
#  'p95.tc_base_max',
#  'p99.tc_base_max',
#  'iqr.tc_base_max',
#  'min.tc_base_p50',
#  'max.tc_base_p50',
#  'mean.tc_base_p50',
#  'std.tc_base_p50',
#  'p1.tc_base_p50',
#  'p5.tc_base_p50',
#  'p10.tc_base_p50',
#  'p20.tc_base_p50',
#  'p30.tc_base_p50',
#  'p40.tc_base_p50',
#  'p50.tc_base_p50',
#  'p60.tc_base_p50',
#  'p70.tc_base_p50',
#  'p80.tc_base_p50',
#  'p90.tc_base_p50',
#  'p95.tc_base_p50',
#  'p99.tc_base_p50',
#  'iqr.tc_base_p50',
#  'min.psa_score_ratio',
#  'max.psa_score_ratio',
#  'mean.psa_score_ratio',
#  'std.psa_score_ratio',
#  'p1.psa_score_ratio',
#  'p5.psa_score_ratio',
#  'p10.psa_score_ratio',
#  'p20.psa_score_ratio',
#  'p30.psa_score_ratio',
#  'p40.psa_score_ratio',
#  'p50.psa_score_ratio',
#  'p60.psa_score_ratio',
#  'p70.psa_score_ratio',
#  'p80.psa_score_ratio',
#  'p90.psa_score_ratio',
#  'p95.psa_score_ratio',
#  'p99.psa_score_ratio',
#  'iqr.psa_score_ratio',
#  'min.psa_gap_len_mean',
#  'max.psa_gap_len_mean',
#  'mean.psa_gap_len_mean',
#  'std.psa_gap_len_mean',
#  'p1.psa_gap_len_mean',
#  'p5.psa_gap_len_mean',
#  'p10.psa_gap_len_mean',
#  'p20.psa_gap_len_mean',
#  'p30.psa_gap_len_mean',
#  'p40.psa_gap_len_mean',
#  'p50.psa_gap_len_mean',
#  'p60.psa_gap_len_mean',
#  'p70.psa_gap_len_mean',
#  'p80.psa_gap_len_mean',
#  'p90.psa_gap_len_mean',
#  'p95.psa_gap_len_mean',
#  'p99.psa_gap_len_mean',
#  'iqr.psa_gap_len_mean',
#  'min.psa_gap_len_p50',
#  'max.psa_gap_len_p50',
#  'mean.psa_gap_len_p50',
#  'std.psa_gap_len_p50',
#  'p1.psa_gap_len_p50',
#  'p5.psa_gap_len_p50',
#  'p10.psa_gap_len_p50',
#  'p20.psa_gap_len_p50',
#  'p30.psa_gap_len_p50',
#  'p40.psa_gap_len_p50',
#  'p50.psa_gap_len_p50',
#  'p60.psa_gap_len_p50',
#  'p70.psa_gap_len_p50',
#  'p80.psa_gap_len_p50',
#  'p90.psa_gap_len_p50',
#  'p95.psa_gap_len_p50',
#  'p99.psa_gap_len_p50',
#  'iqr.psa_gap_len_p50',
#  'min.psa_gap_len_std',
#  'max.psa_gap_len_std',
#  'mean.psa_gap_len_std',
#  'std.psa_gap_len_std',
#  'p1.psa_gap_len_std',
#  'p5.psa_gap_len_std',
#  'p10.psa_gap_len_std',
#  'p20.psa_gap_len_std',
#  'p30.psa_gap_len_std',
#  'p40.psa_gap_len_std',
#  'p50.psa_gap_len_std',
#  'p60.psa_gap_len_std',
#  'p70.psa_gap_len_std',
#  'p80.psa_gap_len_std',
#  'p90.psa_gap_len_std',
#  'p95.psa_gap_len_std',
#  'p99.psa_gap_len_std',
#  'iqr.psa_gap_len_std',
#  'min.psa_gap_len_iqr',
#  'max.psa_gap_len_iqr',
#  'mean.psa_gap_len_iqr',
#  'std.psa_gap_len_iqr',
#  'p1.psa_gap_len_iqr',
#  'p5.psa_gap_len_iqr',
#  'p10.psa_gap_len_iqr',
#  'p20.psa_gap_len_iqr',
#  'p30.psa_gap_len_iqr',
#  'p40.psa_gap_len_iqr',
#  'p50.psa_gap_len_iqr',
#  'p60.psa_gap_len_iqr',
#  'p70.psa_gap_len_iqr',
#  'p80.psa_gap_len_iqr',
#  'p90.psa_gap_len_iqr',
#  'p95.psa_gap_len_iqr',
#  'p99.psa_gap_len_iqr',
#  'iqr.psa_gap_len_iqr',
#  'min.psa_gap_len_logdiff',
#  'max.psa_gap_len_logdiff',
#  'mean.psa_gap_len_logdiff',
#  'std.psa_gap_len_logdiff',
#  'p1.psa_gap_len_logdiff',
#  'p5.psa_gap_len_logdiff',
#  'p10.psa_gap_len_logdiff',
#  'p20.psa_gap_len_logdiff',
#  'p30.psa_gap_len_logdiff',
#  'p40.psa_gap_len_logdiff',
#  'p50.psa_gap_len_logdiff',
#  'p60.psa_gap_len_logdiff',
#  'p70.psa_gap_len_logdiff',
#  'p80.psa_gap_len_logdiff',
#  'p90.psa_gap_len_logdiff',
#  'p95.psa_gap_len_logdiff',
#  'p99.psa_gap_len_logdiff',
#  'iqr.psa_gap_len_logdiff',
#  'min.3mer_js',
#  'max.3mer_js',
#  'mean.3mer_js',
#  'std.3mer_js',
#  'p1.3mer_js',
#  'p5.3mer_js',
#  'p10.3mer_js',
#  'p20.3mer_js',
#  'p30.3mer_js',
#  'p40.3mer_js',
#  'p50.3mer_js',
#  'p60.3mer_js',
#  'p70.3mer_js',
#  'p80.3mer_js',
#  'p90.3mer_js',
#  'p95.3mer_js',
#  'p99.3mer_js',
#  'iqr.3mer_js',
#  'min.3mer_ent',
#  'max.3mer_ent',
#  'mean.3mer_ent',
#  'std.3mer_ent',
#  'p1.3mer_ent',
#  'p5.3mer_ent',
#  'p10.3mer_ent',
#  'p20.3mer_ent',
#  'p30.3mer_ent',
#  'p40.3mer_ent',
#  'p50.3mer_ent',
#  'p60.3mer_ent',
#  'p70.3mer_ent',
#  'p80.3mer_ent',
#  'p90.3mer_ent',
#  'p95.3mer_ent',
#  'p99.3mer_ent',
#  'iqr.3mer_ent',
#  'min.5mer_js',
#  'max.5mer_js',
#  'mean.5mer_js',
#  'std.5mer_js',
#  'p1.5mer_js',
#  'p5.5mer_js',
#  'p10.5mer_js',
#  'p20.5mer_js',
#  'p30.5mer_js',
#  'p40.5mer_js',
#  'p50.5mer_js',
#  'p60.5mer_js',
#  'p70.5mer_js',
#  'p80.5mer_js',
#  'p90.5mer_js',
#  'p95.5mer_js',
#  'p99.5mer_js',
#  'iqr.5mer_js',
#  'min.5mer_ent',
#  'max.5mer_ent',
#  'mean.5mer_ent',
#  'std.5mer_ent',
#  'p1.5mer_ent',
#  'p5.5mer_ent',
#  'p10.5mer_ent',
#  'p20.5mer_ent',
#  'p30.5mer_ent',
#  'p40.5mer_ent',
#  'p50.5mer_ent',
#  'p60.5mer_ent',
#  'p70.5mer_ent',
#  'p80.5mer_ent',
#  'p90.5mer_ent',
#  'p95.5mer_ent',
#  'p99.5mer_ent',
#  'iqr.5mer_ent',
#  'min.7mer_js',
#  'max.7mer_js',
#  'mean.7mer_js',
#  'std.7mer_js',
#  'p1.7mer_js',
#  'p5.7mer_js',
#  'p10.7mer_js',
#  'p20.7mer_js',
#  'p30.7mer_js',
#  'p40.7mer_js',
#  'p50.7mer_js',
#  'p60.7mer_js',
#  'p70.7mer_js',
#  'p80.7mer_js',
#  'p90.7mer_js',
#  'p95.7mer_js',
#  'p99.7mer_js',
#  'iqr.7mer_js',
#  'min.7mer_ent',
#  'max.7mer_ent',
#  'mean.7mer_ent',
#  'std.7mer_ent',
#  'p1.7mer_ent',
#  'p5.7mer_ent',
#  'p10.7mer_ent',
#  'p20.7mer_ent',
#  'p30.7mer_ent',
#  'p40.7mer_ent',
#  'p50.7mer_ent',
#  'p60.7mer_ent',
#  'p70.7mer_ent',
#  'p80.7mer_ent',
#  'p90.7mer_ent',
#  'p95.7mer_ent',
#  'p99.7mer_ent',
#  'iqr.7mer_ent',
#  'min.9mer_js',
#  'max.9mer_js',
#  'mean.9mer_js',
#  'std.9mer_js',
#  'p1.9mer_js',
#  'p5.9mer_js',
#  'p10.9mer_js',
#  'p20.9mer_js',
#  'p30.9mer_js',
#  'p40.9mer_js',
#  'p50.9mer_js',
#  'p60.9mer_js',
#  'p70.9mer_js',
#  'p80.9mer_js',
#  'p90.9mer_js',
#  'p95.9mer_js',
#  'p99.9mer_js',
#  'iqr.9mer_js',
#  'min.9mer_ent',
#  'max.9mer_ent',
#  'mean.9mer_ent',
#  'std.9mer_ent',
#  'p1.9mer_ent',
#  'p5.9mer_ent',
#  'p10.9mer_ent',
#  'p20.9mer_ent',
#  'p30.9mer_ent',
#  'p40.9mer_ent',
#  'p50.9mer_ent',
#  'p60.9mer_ent',
#  'p70.9mer_ent',
#  'p80.9mer_ent',
#  'p90.9mer_ent',
#  'p95.9mer_ent',
#  'p99.9mer_ent',
#  'iqr.9mer_ent']

# %%
imp_df = pd.concat([pd.Series(clean_feat_names), pd.Series(imps)], axis=1)
imp_df.columns = ["name", "gain"]
imp_df
imp_df["group"] = pd.Series(imp_df.name.str.split(".").map(lambda v: v[-1]))
imp_df.sort_values("gain", ascending=False)
print(set(imp_df.group))
for pat in [
    "mean",
    "min",
    "max",
    "mean",
    "iqr",
    "p50",
    "std",
    # "count",
    # "len",
    # "len_logdiff",
]:
    imp_df.group = imp_df.group.str.rsplit("_" + pat).map(lambda v: v[0])
groups = set(imp_df.group)
groups
# Out:
# {'frst_entropy', 'js_hpoly_count', 'lower_bound_gap_percentage', 'js_char', 'tc_base_p50', 'frst_serial-correlation', 'tc_base_min', '5mer_ent', 'psa_score_ratio', 'psa_gap_len_p50', 'tc_base_std', 'tc_base_mean', '3mer_ent', '3mer_js', 'frst_mean', '9mer_js', 'frst_inv-chi-square', '7mer_js', 'psa_gap_len_std', '9mer_ent', '7mer_ent', '5mer_js', 'psa_gap_len_iqr', 'psa_gap_len_logdiff', 'psa_gap_len_mean', 'tc_base_max', 'js_hpoly_len'}
# {'3mer_ent',
#  '3mer_js',
#  '5mer_ent',
#  '5mer_js',
#  '7mer_ent',
#  '7mer_js',
#  '9mer_ent',
#  '9mer_js',
#  'frst',
#  'frst_entropy',
#  'frst_inv-chi-square',
#  'frst_serial-correlation',
#  'js_char',
#  'js_hpoly_count',
#  'js_hpoly_len',
#  'lower_bound_gap_percentage',
#  'psa_gap_len',
#  'psa_gap_len_logdiff',
#  'psa_score_ratio',
#  'tc_base'}

# %%
imp_df.groupby("group").max(numeric_only=True).sort_values("gain", ascending=False)
# Out:
#                                   gain
# group
# tc_base                     598.068310
# psa_score_ratio              80.090993
# 7mer_js                      52.229560
# 9mer_ent                     30.016441
# 5mer_js                      24.973104
# lower_bound_gap_percentage   17.674184
# psa_gap_len                  16.433802
# 7mer_ent                     10.609474
# 9mer_js                      10.589220
# 5mer_ent                      6.765510
# js_char                       6.223726
# 3mer_js                       3.719502
# frst                          3.340757
# frst_inv-chi-square           3.261199
# frst_entropy                  2.718748
# js_hpoly_len                  2.501253
# js_hpoly_count                2.437979
# psa_gap_len_logdiff           2.405074
# frst_serial-correlation       2.350916
# 3mer_ent                      1.918216

# %%
# Feature classes:
# - tc_base : Transitive consistency of sequence triplets
# - psa_score_ratio : Alignment score scaled by the minimum sequence length
# - kmer_js : Pairwise Jensen-Shannon divergence of kmer distributions
# - kmer_ent : Entropy of kmer distributions
# - lbgp : Lower bound on the percentage of gaps
# - psa_gap :
